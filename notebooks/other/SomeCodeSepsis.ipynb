# %% [markdown]
# ### Some Spesis Code

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
df = pd.read_csv('train_patient3.csv')
df.shape
# Out:
# (1552210, 43)

# %%
df.head()
# Out:
#      HR  O2Sat   Temp    SBP    MAP  DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 0   NaN    NaN    NaN    NaN    NaN  NaN   NaN    NaN         NaN   NaN  ...
# 1  85.0  100.0    NaN  121.0  79.67  NaN  16.0    NaN         NaN   NaN  ...
# 2  72.0  100.0    NaN  110.0  72.67  NaN  16.0    NaN         NaN  24.0  ...
# 3  74.0  100.0    NaN  109.0  75.00  NaN  16.0    NaN         NaN   NaN  ...
# 4  75.0  100.0  37.39  104.0  70.00  NaN  16.0    NaN         NaN   NaN  ...
#
#    Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  ICULOS  SepsisLabel  \
# 0        NaN  60.08       1    NaN    NaN        -0.01       1            0
# 1        NaN  60.08       1    NaN    NaN        -0.01       2            0
# 2      237.0  60.08       1    NaN    NaN        -0.01       3            0
# 3        NaN  60.08       1    NaN    NaN        -0.01       4            0
# 4        NaN  60.08       1    NaN    NaN        -0.01       5            0
#
#    Patient_id  time
# 0           0     0
# ...

# %%
df[df['SepsisLabel']==1].head()
# Out:
#        HR  O2Sat   Temp    SBP   MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 851  92.0   98.0    NaN  151.0  79.0  47.0  27.0    NaN         NaN   NaN
# 852  94.5   98.5    NaN  162.5  91.0  54.5  24.0    NaN         NaN   NaN
# 853  84.0   97.0    NaN  148.0  75.0  42.0  24.0    NaN         NaN   NaN
# 854  84.0   96.0  37.56  155.0  84.0  48.0  18.0    NaN         NaN   NaN
# 855  84.0   97.0    NaN  152.0  87.0  52.0  27.0    NaN         NaN   NaN
#
#      ...  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  ICULOS  \
# 851  ...        NaN  73.94       0    NaN    NaN        -8.18     245
# 852  ...        NaN  73.94       0    NaN    NaN        -8.18     246
# 853  ...        NaN  73.94       0    NaN    NaN        -8.18     247
# 854  ...        NaN  73.94       0    NaN    NaN        -8.18     248
# 855  ...        NaN  73.94       0    NaN    NaN        -8.18     249
#
#      SepsisLabel  Patient_id  time
# 851            1          16   244
# ...

# %%
df[df['Patient_id']==16]
# Out:
#        HR  O2Sat   Temp    SBP    MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 607   NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN         NaN   NaN
# 608  66.0  100.0    NaN  120.0  54.00  42.0  19.0    NaN         NaN   NaN
# 609  64.0  100.0  36.11  106.5  51.67  46.0  16.0    NaN         NaN   NaN
# 610  67.0    NaN    NaN  104.0  56.00   NaN   NaN    NaN         NaN   NaN
# 611  68.0  100.0  36.67  145.0  82.00  46.0  22.0    NaN       -11.0   NaN
# ..    ...    ...    ...    ...    ...   ...   ...    ...         ...   ...
# 856  82.0   97.0    NaN  153.0  84.00  50.0  22.0    NaN         NaN  30.0
# 857  73.0   97.0    NaN  141.0  77.00  46.0  21.0    NaN         3.0   NaN
# 858  72.0   97.0  37.06  133.0  75.00  47.0  23.0    NaN         NaN   NaN
# 859  77.0   98.0    NaN  154.0  84.00  50.0  22.5    NaN         2.0   NaN
# 860  73.0   98.0    NaN  130.0  70.00  42.0  23.0    NaN         NaN   NaN
#
# ...

# %%
df[df['Patient_id']==16]['SepsisLabel'].value_counts()
# Out:
# 0    244
# 1     10
# Name: SepsisLabel, dtype: int64

# %%
pt_no16_df=df[df['Patient_id']==16]
pt_no16_df.head()
# Out:
#        HR  O2Sat   Temp    SBP    MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 607   NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN         NaN   NaN
# 608  66.0  100.0    NaN  120.0  54.00  42.0  19.0    NaN         NaN   NaN
# 609  64.0  100.0  36.11  106.5  51.67  46.0  16.0    NaN         NaN   NaN
# 610  67.0    NaN    NaN  104.0  56.00   NaN   NaN    NaN         NaN   NaN
# 611  68.0  100.0  36.67  145.0  82.00  46.0  22.0    NaN       -11.0   NaN
#
#      ...  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  ICULOS  \
# 607  ...        NaN  73.94       0    NaN    NaN        -8.18       1
# 608  ...        NaN  73.94       0    NaN    NaN        -8.18       2
# 609  ...        NaN  73.94       0    NaN    NaN        -8.18       3
# 610  ...        NaN  73.94       0    NaN    NaN        -8.18       4
# 611  ...        NaN  73.94       0    NaN    NaN        -8.18       5
#
#      SepsisLabel  Patient_id  time
# 607            0          16     0
# ...

# %%
sns.pairplot(pt_no16_df, hue='SepsisLabel', size=2.5);

# %%
sns.pairplot(df, hue='SepsisLabel', size=2.5);

# %%
pt_no16_df.hist(figsize=(15, 15), bins=50);

# %%
pt_no16_df['HR'].plot()
# Out:
# <AxesSubplot:>

# %%
pt_no16_df['MAP'].plot()
# Out:
# <AxesSubplot:>

# %%
(pt_no16_df.isnull().sum().sort_values(ascending=False)/pt_no16_df.isnull().count()).sort_values(ascending=False)
# Out:
# AST                 1.000000
# Alkalinephos        1.000000
# EtCO2               1.000000
# Fibrinogen          1.000000
# Bilirubin_direct    1.000000
# Bilirubin_total     1.000000
# Unit2               1.000000
# Unit1               1.000000
# TroponinI           1.000000
# SaO2                0.996063
# PTT                 0.992126
# Magnesium           0.956693
# HCO3                0.956693
# BUN                 0.956693
# WBC                 0.956693
# Creatinine          0.956693
# Phosphate           0.956693
# Platelets           0.956693
# Chloride            0.956693
# Calcium             0.956693
# Lactate             0.948819
# Hgb                 0.948819
# Hct                 0.944882
# Potassium           0.925197
# BaseExcess          0.854331
# pH                  0.854331
# PaCO2               0.854331
# Glucose             0.838583
# Temp                0.700787
# FiO2                0.661417
# DBP                 0.118110
# O2Sat               0.031496
# ...

# %%
mis_values = (df.isnull().sum() / df.shape[0]) * 100

# %%
selected_cols = list(mis_values[mis_values < 83].index)
selected_cols
# Out:
# ['HR',
#  'O2Sat',
#  'Temp',
#  'SBP',
#  'MAP',
#  'DBP',
#  'Resp',
#  'Glucose',
#  'Age',
#  'Gender',
#  'Unit1',
#  'Unit2',
#  'HospAdmTime',
#  'ICULOS',
#  'SepsisLabel',
#  'Patient_id',
#  'time']

# %%
no_sixteen=pt_no16_df[selected_cols]

# %%
no_sixteen.head()
# Out:
#        HR  O2Sat   Temp    SBP    MAP   DBP  Resp  Glucose    Age  Gender  \
# 607   NaN    NaN    NaN    NaN    NaN   NaN   NaN      NaN  73.94       0
# 608  66.0  100.0    NaN  120.0  54.00  42.0  19.0      NaN  73.94       0
# 609  64.0  100.0  36.11  106.5  51.67  46.0  16.0      NaN  73.94       0
# 610  67.0    NaN    NaN  104.0  56.00   NaN   NaN      NaN  73.94       0
# 611  68.0  100.0  36.67  145.0  82.00  46.0  22.0    395.0  73.94       0
#
#      Unit1  Unit2  HospAdmTime  ICULOS  SepsisLabel  Patient_id  time
# 607    NaN    NaN        -8.18       1            0          16     0
# 608    NaN    NaN        -8.18       2            0          16     1
# 609    NaN    NaN        -8.18       3            0          16     2
# 610    NaN    NaN        -8.18       4            0          16     3
# 611    NaN    NaN        -8.18       5            0          16     4

# %%
corr = no_sixteen.corr()
sns.heatmap(corr);

# %%
no_sixteen.drop(['Age',
 'Gender',
 'Unit1',
 'Unit2',
 'HospAdmTime',
 'ICULOS',
 'SepsisLabel',
 'Patient_id',
 'time'], axis = 1, inplace = True)
# Out:
# C:\Users\lhour\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
no_sixteen.head()
# Out:
#        HR  O2Sat   Temp    SBP    MAP   DBP  Resp  Glucose
# 607   NaN    NaN    NaN    NaN    NaN   NaN   NaN      NaN
# 608  66.0  100.0    NaN  120.0  54.00  42.0  19.0      NaN
# 609  64.0  100.0  36.11  106.5  51.67  46.0  16.0      NaN
# 610  67.0    NaN    NaN  104.0  56.00   NaN   NaN      NaN
# 611  68.0  100.0  36.67  145.0  82.00  46.0  22.0    395.0

# %%
corr2 = no_sixteen.corr()
sns.heatmap(corr2);

# %%
no_sixteen.plot()
# Out:
# <AxesSubplot:>

# %%
no_sixteen['MAP'].plot()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(no_sixteen);

# %%
df.head()
# Out:
#      HR  O2Sat   Temp    SBP    MAP  DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 0   NaN    NaN    NaN    NaN    NaN  NaN   NaN    NaN         NaN   NaN  ...
# 1  85.0  100.0    NaN  121.0  79.67  NaN  16.0    NaN         NaN   NaN  ...
# 2  72.0  100.0    NaN  110.0  72.67  NaN  16.0    NaN         NaN  24.0  ...
# 3  74.0  100.0    NaN  109.0  75.00  NaN  16.0    NaN         NaN   NaN  ...
# 4  75.0  100.0  37.39  104.0  70.00  NaN  16.0    NaN         NaN   NaN  ...
#
#    Phosphate  Potassium  Bilirubin_total  TroponinI   Hct  Hgb  PTT   WBC  \
# 0        NaN        NaN              NaN        NaN   NaN  NaN  NaN   NaN
# 1        NaN        NaN              NaN        NaN   NaN  NaN  NaN   NaN
# 2        2.8        4.2              NaN        NaN  36.8  NaN  NaN  10.5
# 3        NaN        NaN              NaN        NaN   NaN  NaN  NaN   NaN
# 4        NaN        NaN              NaN        NaN   NaN  NaN  NaN   NaN
#
#    Fibrinogen  Platelets
# 0         NaN        NaN
# ...
