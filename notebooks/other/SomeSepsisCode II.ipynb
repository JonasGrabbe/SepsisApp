# %% [markdown]
# ### Some Spesis Code II

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
df = pd.read_csv('train_patient3.csv')
df.shape
# Out:
# (1552210, 43)

# %%
df.head()
# Out:
#      HR  O2Sat   Temp    SBP    MAP  DBP  Resp  EtCO2  BaseExcess  HCO3  ...  \
# 0   NaN    NaN    NaN    NaN    NaN  NaN   NaN    NaN         NaN   NaN  ...
# 1  85.0  100.0    NaN  121.0  79.67  NaN  16.0    NaN         NaN   NaN  ...
# 2  72.0  100.0    NaN  110.0  72.67  NaN  16.0    NaN         NaN  24.0  ...
# 3  74.0  100.0    NaN  109.0  75.00  NaN  16.0    NaN         NaN   NaN  ...
# 4  75.0  100.0  37.39  104.0  70.00  NaN  16.0    NaN         NaN   NaN  ...
#
#    Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  ICULOS  SepsisLabel  \
# 0        NaN  60.08       1    NaN    NaN        -0.01       1            0
# 1        NaN  60.08       1    NaN    NaN        -0.01       2            0
# 2      237.0  60.08       1    NaN    NaN        -0.01       3            0
# 3        NaN  60.08       1    NaN    NaN        -0.01       4            0
# 4        NaN  60.08       1    NaN    NaN        -0.01       5            0
#
#    Patient_id  time
# 0           0     0
# ...

# %%
lab=['BaseExcess','HCO3','FiO2','pH','PaCO2','SaO2','AST','BUN','Alkalinephos','Calcium','Chloride','Creatinine','Bilirubin_direct','Glucose','Lactate',
      'Magnesium','Phosphate','Potassium','Bilirubin_total','TroponinI','Hct','Hgb','PTT','WBC','Fibrinogen','Platelets']

vitals = ['HR','O2Sat','Temp','SBP','MAP','DBP','Resp','EtCO2']

demo = ['Age','Gender','Unit1','Unit2','HospAdmTime','ICULOS']

label = ['SepsisLabel']

# %%
df.drop(['BaseExcess','HCO3','FiO2','pH','PaCO2','SaO2','AST','Alkalinephos','Calcium','Chloride','Magnesium','Phosphate','Potassium','TroponinI','Hct','Hgb','PTT','WBC','Fibrinogen','Platelets','Unit1','Unit2','HospAdmTime'], axis = 1, inplace = True)

# %%
sns.pairplot(df[demo])
# Out:
# Error in callback <function flush_figures at 0x00000167D3462AF0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
df[demo].head()
# Out:
#      Age  Gender  Unit1  Unit2  HospAdmTime  ICULOS
# 0  60.08       1    NaN    NaN        -0.01       1
# 1  60.08       1    NaN    NaN        -0.01       2
# 2  60.08       1    NaN    NaN        -0.01       3
# 3  60.08       1    NaN    NaN        -0.01       4
# 4  60.08       1    NaN    NaN        -0.01       5

# %%
sns.pairplot(df[vitals], hue='SepsisLabel')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SepsisLabel'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-58d20739efef> in <module>
# ...

# %%
df.dtypes
# Out:
# HR                  float64
# O2Sat               float64
# Temp                float64
# SBP                 float64
# MAP                 float64
# DBP                 float64
# Resp                float64
# EtCO2               float64
# BaseExcess          float64
# HCO3                float64
# FiO2                float64
# pH                  float64
# PaCO2               float64
# SaO2                float64
# AST                 float64
# BUN                 float64
# Alkalinephos        float64
# Calcium             float64
# Chloride            float64
# Creatinine          float64
# Bilirubin_direct    float64
# Glucose             float64
# Lactate             float64
# Magnesium           float64
# Phosphate           float64
# Potassium           float64
# Bilirubin_total     float64
# TroponinI           float64
# Hct                 float64
# Hgb                 float64
# PTT                 float64
# WBC                 float64
# Fibrinogen          float64
# ...

# %%
 df['SepsisLabel'] = df['SepsisLabel'].astype('category',copy=False)

# %%
df.dtypes
# Out:
# HR                   float64
# O2Sat                float64
# Temp                 float64
# SBP                  float64
# MAP                  float64
# DBP                  float64
# Resp                 float64
# EtCO2                float64
# BaseExcess           float64
# HCO3                 float64
# FiO2                 float64
# pH                   float64
# PaCO2                float64
# SaO2                 float64
# AST                  float64
# BUN                  float64
# Alkalinephos         float64
# Calcium              float64
# Chloride             float64
# Creatinine           float64
# Bilirubin_direct     float64
# Glucose              float64
# Lactate              float64
# Magnesium            float64
# Phosphate            float64
# Potassium            float64
# Bilirubin_total      float64
# TroponinI            float64
# Hct                  float64
# Hgb                  float64
# PTT                  float64
# WBC                  float64
# ...

# %%
stsofa=['MAP','BUN','Creatinine','SBP','HR','Temp','Bilirubin_direct']
df[stsofa].head()
# Out:
#      MAP   BUN  Creatinine    SBP    HR   Temp  Bilirubin_direct
# 0    NaN   NaN         NaN    NaN   NaN    NaN               NaN
# 1  79.67   NaN         NaN  121.0  85.0    NaN               NaN
# 2  72.67  16.0         1.2  110.0  72.0    NaN               NaN
# 3  75.00   NaN         NaN  109.0  74.0    NaN               NaN
# 4  70.00   NaN         NaN  104.0  75.0  37.39               NaN

# %%
sns.pairplot(df[stsofa])

# %%
sns.pairplot(df[stsofa], hue='SepsisLabel')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SepsisLabel'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-b23729189053> in <module>
# ...

# %%
stsofa=['MAP','BUN','Creatinine','SBP','HR','Temp','Bilirubin_direct']
shockIndex=['MAP','BUN','HR','SepsisLabel']
df[shockIndex].head()
# Out:
#      MAP   BUN    HR SepsisLabel
# 0    NaN   NaN   NaN           0
# 1  79.67   NaN  85.0           0
# 2  72.67  16.0  72.0           0
# 3  75.00   NaN  74.0           0
# 4  70.00   NaN  75.0           0

# %%
sns.pairplot(df[shockIndex], hue='SepsisLabel')

# %%
df2=df[df['SepsisLabel']==1][shockIndex]
df2.head()
# Out:
#       MAP  BUN    HR SepsisLabel
# 851  79.0  NaN  92.0           1
# 852  91.0  NaN  94.5           1
# 853  75.0  NaN  84.0           1
# 854  84.0  NaN  84.0           1
# 855  87.0  NaN  84.0           1

# %%
sns.pairplot(df2, hue='SepsisLabel')

# %%
df3=df[df['Patient_id']==16]
df3.head()
# Out:
#        HR  O2Sat   Temp    SBP    MAP   DBP  Resp  EtCO2  BaseExcess  HCO3  \
# 607   NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN         NaN   NaN
# 608  66.0  100.0    NaN  120.0  54.00  42.0  19.0    NaN         NaN   NaN
# 609  64.0  100.0  36.11  106.5  51.67  46.0  16.0    NaN         NaN   NaN
# 610  67.0    NaN    NaN  104.0  56.00   NaN   NaN    NaN         NaN   NaN
# 611  68.0  100.0  36.67  145.0  82.00  46.0  22.0    NaN       -11.0   NaN
#
#      ...  Platelets    Age  Gender  Unit1  Unit2  HospAdmTime  ICULOS  \
# 607  ...        NaN  73.94       0    NaN    NaN        -8.18       1
# 608  ...        NaN  73.94       0    NaN    NaN        -8.18       2
# 609  ...        NaN  73.94       0    NaN    NaN        -8.18       3
# 610  ...        NaN  73.94       0    NaN    NaN        -8.18       4
# 611  ...        NaN  73.94       0    NaN    NaN        -8.18       5
#
#      SepsisLabel  Patient_id  time
# 607            0          16     0
# ...

# %%
sns.pairplot(df2[stsofa], hue='SepsisLabel')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-2f7d456a6619> in <module>
# ----> 1 sns.pairplot(df2[stsofa], hue='SepsisLabel')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# ...

# %%
df3.columns
# Out:
# Index(['HR', 'O2Sat', 'Temp', 'SBP', 'MAP', 'DBP', 'Resp', 'EtCO2',
#        'BaseExcess', 'HCO3', 'FiO2', 'pH', 'PaCO2', 'SaO2', 'AST', 'BUN',
#        'Alkalinephos', 'Calcium', 'Chloride', 'Creatinine', 'Bilirubin_direct',
#        'Glucose', 'Lactate', 'Magnesium', 'Phosphate', 'Potassium',
#        'Bilirubin_total', 'TroponinI', 'Hct', 'Hgb', 'PTT', 'WBC',
#        'Fibrinogen', 'Platelets', 'Age', 'Gender', 'Unit1', 'Unit2',
#        'HospAdmTime', 'ICULOS', 'SepsisLabel', 'Patient_id', 'time'],
#       dtype='object')

# %%
stsofa=['MAP','BUN','Creatinine','SBP','HR','Temp','Bilirubin_direct']
shockIndex=['MAP','BUN','HR','SepsisLabel']
df.drop(['O2Sat','EtCO2',
       'BaseExcess', 'HCO3','pH', 'PaCO2', 'SaO2', 'AST', 'Alkalinephos', 'Calcium', 'Chloride', 'Magnesium', 'Phosphate', 'Potassium', 'TroponinI', 'Hct', 'Hgb','Fibrinogen', 'Unit1', 'Unit2','time'], axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['HR', 'Temp', 'SBP', 'MAP', 'DBP', 'Resp', 'FiO2', 'BUN', 'Creatinine',
#        'Bilirubin_direct', 'Glucose', 'Lactate', 'Bilirubin_total', 'PTT',
#        'WBC', 'Platelets', 'Age', 'Gender', 'HospAdmTime', 'ICULOS',
#        'SepsisLabel', 'Patient_id'],
#       dtype='object')

# %%
sixTeen=df[df['Patient_id']==16]
sixTeen.head()
# Out:
#        HR   Temp    SBP    MAP   DBP  Resp  FiO2  BUN  Creatinine  \
# 607   NaN    NaN    NaN    NaN   NaN   NaN   NaN  NaN         NaN
# 608  66.0    NaN  120.0  54.00  42.0  19.0   0.5  NaN         NaN
# 609  64.0  36.11  106.5  51.67  46.0  16.0   0.5  NaN         NaN
# 610  67.0    NaN  104.0  56.00   NaN   NaN   NaN  NaN         NaN
# 611  68.0  36.67  145.0  82.00  46.0  22.0   0.5  NaN         NaN
#
#      Bilirubin_direct  ...  Bilirubin_total  PTT  WBC  Platelets    Age  \
# 607               NaN  ...              NaN  NaN  NaN        NaN  73.94
# 608               NaN  ...              NaN  NaN  NaN        NaN  73.94
# 609               NaN  ...              NaN  NaN  NaN        NaN  73.94
# 610               NaN  ...              NaN  NaN  NaN        NaN  73.94
# 611               NaN  ...              NaN  NaN  NaN        NaN  73.94
#
#      Gender  HospAdmTime  ICULOS  SepsisLabel  Patient_id
# 607       0        -8.18       1            0          16
# ...

# %%
sns.pairplot(sixTeen, hue='SepsisLabel')
# Out:
# C:\Users\lhour\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lhour\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lhour\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lhour\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lhour\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
stsofa=['MAP','BUN','Creatinine','SBP','HR','Temp','Bilirubin_direct','SepsisLabel']
shockIndex=['MAP','BUN','HR','SepsisLabel']

# %%
sns.pairplot(sixTeen[stsofa], hue='SepsisLabel')
# Out:
# C:\Users\lhour\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lhour\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(sixTeen[shockIndex], hue='SepsisLabel')
# Out:
# C:\Users\lhour\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
sixTeen.plot()
# Out:
# <AxesSubplot:>

# %%
sixTeen[stsofa].plot()
# Out:
# <AxesSubplot:>

# %%
sixTeen[shockIndex].plot()
# Out:
# <AxesSubplot:>

# %%
sixTeen['MAP'].values
# Out:
# array([   nan,  54.  ,  51.67,  56.  ,  82.  ,  75.  ,  69.  ,  66.  ,
#         64.  ,  71.  ,  79.  ,  85.  ,  83.  ,  79.  ,  84.  , 107.  ,
#         76.33,  63.  ,  52.33,  61.67,  49.33,  70.67,  62.  ,  81.33,
#         82.67,  80.  ,  75.33,  86.33,  86.67,  77.  ,  66.  ,  73.67,
#         86.67,  72.  ,  94.  ,  81.  ,  84.67,  91.  , 103.67,  85.  ,
#         78.67,  66.33,  69.33,  60.67,  70.  ,  74.  ,  76.  ,  86.  ,
#         78.  ,  91.  ,  68.  ,  76.  ,  58.  ,  70.  ,  73.  ,  73.  ,
#         79.  ,  82.  ,  79.  ,  83.  ,  80.  ,  66.  ,  84.  ,  89.  ,
#        103.  ,  57.  ,  77.  ,  79.  ,  60.  ,  70.  ,  83.  ,  84.  ,
#         77.  ,  81.  ,  77.  ,  83.  ,  88.  ,  94.  ,  82.  ,  72.  ,
#         72.  ,  65.  ,  63.  ,  71.  ,  70.  ,  75.  ,  75.  ,  78.  ,
#         68.  ,  66.  ,  66.  ,  72.  ,  68.  ,  70.  ,  69.  ,  77.  ,
#         70.  ,  73.  ,  70.5 ,  93.  ,  81.  ,  70.  ,  78.  ,  84.  ,
# ...

# %%
sixTeen['MAP'].values.size
# Out:
# 254

# %%
sixTeen['MAP'].plot()
# Out:
# <AxesSubplot:>
